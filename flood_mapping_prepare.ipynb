# %%
import digitalhub as dh

project = dh.get_or_create_project('remote-sensing')

# %%
try:
    artifact = project.get_artifact('areas')
except:
    artifact = project.log_artifact('areas', kind='artifact', source='./shapes')
