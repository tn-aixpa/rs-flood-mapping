# %%
import digitalhub as dh
import os
PROJECT_NAME = "flood-map-detection"
project = dh.get_or_create_project(PROJECT_NAME)

# %%
new_folder ='src'
if not os.path.exists(new_folder):
    os.makedirs(new_folder)

# %%
# config as artifact
# di = project.new_artifact(name="config",kind="artifact", path="./config.ini")

# %%
# Secret
project.new_secret(name="private_key_json", secret_value="{\r\n  \"type\": \"service_account\",\r\n  \"project_id\": \"dh-platform-rsde\",\r\n  \"private_key_id\": \"47768d7d191b0bc11c433223e9be15f5fe36b938\",\r\n  \"private_key\": \"-----BEGIN PRIVATE KEY-----\\nMIIEvgIBADANBgkqhkiG9w0BAQEFAASCBKgwggSkAgEAAoIBAQCrwWX2vOqw0ikA\\npv42x6bMCExb+vyCCZggGoDC/3cZe866lMMRmbUxJ/Q5tI1Y5+isTVfgPsIF4oDs\\n638ZO6QT+a7u+/EZhaKMOzk363C0QV7oCWGCRl6yJHIEsYzp3uKxDqH3Ozf5UdJD\\nWLGbttpqK6f3KBDvdotjlBlXnGK2C5KIZ6ODYSkNFrHnQBwXzFGwJIRdFblY4CcG\\ni1kfI8Ak48fxTDDOxgz9+12GmXReTy+EvRZxnP4F9A/86DxuJ7un5BUPzQ04ngxq\\n92KJyHnllRVvXQeUgdweH+c+1/tZHM18VlybBpI6/33gRPmj1i5n7CrptvXnHMTE\\n2CaAgP7hAgMBAAECggEAFRi1v1dYFReop/xbDaZ7UzoSYFqVU8b9k7U9q0tOuTzE\\nWUBML5LA4e9QPRrzdlVR9oFaMbXzsLOwIKm9HFUqOQvk/qodOgR4lp9FpBvmuuAB\\nWiCg2gFuaz+KbmTSnqgHvItuvdvdFbeE9fcPJcW8JpNYgnATmHOSo8y9SiNwL9T1\\n6fAJpRf9eWzyQl76KlYogI9V354oM9e5bSAtBFnmjvkFXIYspNL79DOF35AF0Otq\\nbJKlHgMSaYMdlmh2r+5UQAewrnSBXRz/I+dFhCnNr4L5mLPD6bZWARCq9EcD4G6o\\ni2kidXQd47CeLDKH2WLJkm+Tu5k9UkI9BiNPk24t0wKBgQDpgvfu+J42gMCrYesh\\ngJrvP4PBY37PRsRZgipSwArc3zEYnJ2VezLWQb7kRi+pOZ9skcBOMqr4S6sHt43O\\nTLzATyorPh2HpthvlHpgvpCCYcwhnpqrmxgDpyr4qFy8BPalaa1W3HSiOBEtH8Bs\\neNVDbrgWXAO6+Y6R7cNHjSK/7wKBgQC8S+JoIkA5PGN6IxwMCNkQr6zTx0iB1a/0\\nOYu/B0H31hIfUzZ1iQZRNw+q7cNvtD5bCW1BEnxSFi/EkFyYUbFSZe5j7wsfTn/b\\nk1jBYZK5Q114GbY9NObPPsoFHwd3uG9rEm6TH0xnAnxHN6LMgml9OSm1HvuQ763S\\nZ6MTr7peLwKBgD7OThdFYXBxYuD1vkNNjt6Iq8xpEWN4ujkE7JNDOei8Uz02aqAY\\n+cxs9IX7ZrhSWlHeReYCdL/BwmeZ9BcnxqDG6iWlWFXzB0XDnsLEnqOi4D+upBVB\\n6syYutMUnZSolRpaeRfixbAX+m6zmpLSUTII5pSE/S/eDX2sgJiPGmibAoGBALMs\\nmmJwxSAxoI8mPZgOC09fe1uCNDKnvejtoVbDdzh4EYKRUi8BlmtNs7D40pHGt9c0\\n3yuehYIu7oFixVmD0vIPYIrjenft4Kh2S2yohk+YFKcmAE25uy/WFbJN1nNLo2oF\\nfgatL6yNpui1vkpQhkTMUi2xL7y49XRTfdBL1VGtAoGBALtyUGVB3aY0GSHTEzms\\n+fDJMp7k3U/Y8by3i67wP1PdOPqtVSKLFI9xbBA8V/UIc9ItxkDwSsFlapNzwRUy\\n9lDEg8kNNONPl8EShwU5aezDda6ZLHEYRJc1MP3vA1zfGPn8H6P8WbKSL6na8/pR\\nHE7jm22YnA0gzd0xRsZ23Lig\\n-----END PRIVATE KEY-----\\n\",\r\n  \"client_email\": \"dh-platform-rsde@dh-platform-rsde.iam.gserviceaccount.com\",\r\n  \"client_id\": \"109131743593165760279\",\r\n  \"auth_uri\": \"https://accounts.google.com/o/oauth2/auth\",\r\n  \"token_uri\": \"https://oauth2.googleapis.com/token\",\r\n  \"auth_provider_x509_cert_url\": \"https://www.googleapis.com/oauth2/v1/certs\",\r\n  \"client_x509_cert_url\": \"https://www.googleapis.com/robot/v1/metadata/x509/dh-platform-rsde%40dh-platform-rsde.iam.gserviceaccount.com\",\r\n  \"universe_domain\": \"googleapis.com\"\r\n}")
# project.new_secret(name="service_account", secret_value="dh-platform-rsde@dh-platform-rsde.iam.gserviceaccount.com")
# Out:
# {'kind': 'secret', 'metadata': {'project': 'flood-map-detection', 'name': 'private_key_json', 'created': '2025-02-28T10:16:58.735Z', 'updated': '2025-02-28T10:16:58.735Z', 'created_by': 'khurshid@fbk.eu', 'updated_by': 'khurshid@fbk.eu', 'embedded': False}, 'spec': {'path': 'secret://private_key_json', 'provider': 'kubernetes'}, 'status': {'state': 'CREATED'}, 'user': 'khurshid@fbk.eu', 'project': 'flood-map-detection', 'name': 'private_key_json', 'id': 'fbdabb50e7e04ee282a48593df2b4180', 'key': 'store://flood-map-detection/secret/secret/private_key_json:fbdabb50e7e04ee282a48593df2b4180'}

# %%
di = project.get_artifact('config')
di.key
# Out:
# 'store://flood-map-detection/artifact/artifact/config:8dvwgbrq8gk688d4m7ojrxh7'

# %%
# %%writefile "src/flood-map.py"
#
# import configparser
# import ee
# import pandas as pd
# from os import path, makedirs
# from google.auth import compute_engine, impersonated_credentials
# import json
#
# scopes = [
#     "https://www.googleapis.com/auth/earthengine"
# ]
#
# file_basepath = "flood"
# def load(project, config):
#
#     data_dir = f"{file_basepath}/data"
#
#     try:
#         shutil.rmtree(data_dir)
#     except:
#         print("Error deleting flood data dir")
#
#     # Create the directory for the data
#     if not path.exists(data_dir):
#         makedirs(data_dir)
#
#     config_file = config.download(data_dir, overwrite=True)
#
#     # Load the config file
#     config = configparser.ConfigParser()
#     config.read(config_file)
#
#     # Extract parameters from the config file
#     before_event_start = config['GENERAL']['before_event_start']
#     before_event_end = config['GENERAL']['before_event_end']
#     after_event_start = config['GENERAL']['after_event_start']
#     after_event_end = config['GENERAL']['after_event_end']
#     #difference_threshold = float(config['GENERAL']['difference_threshold'])
#     aoi_path = config['INPUT']['aoi_coordinates']
#     s1_collection = config['INPUT']['s1_collection']
#     s2_collection = config['INPUT']['s2_collection']
#     swater_dataset = config['INPUT']['swater_dataset']
#
#     # Read CHIRPS date range from config file
#     chirps_start_date = config['INPUT']['chirps_start_date']
#     chirps_end_date = config['INPUT']['chirps_end_date']
#     output_directory = config['OUTPUT']['output_directory']
#     google_drive_folder = config['OUTPUT']['google_drive_folder']
#
#     # Authenticate and initialize Earth Engine
#     # ee.Authenticate()
#     # ee.Initialize(project='dh-platform-rsde')
#
#     service_account_secret = project.get_secret("service_account")
#     service_account = service_account_secret.read_secret_value()
#     private_key_secret = project.get_secret("private_key_json")
#     private_key_json = private_key_secret.read_secret_value()
#
#     # json_object = json.dumps(dictionary)
#
#     # Writing to sample.json
#     with open(data_dir + '/key.json', "w") as outfile:
#         outfile.write(private_key_json)
#
#     # key_file = json.dumps(json.loads(private_key_json.read_secret_value()))
#
#
#     credentials = ee.ServiceAccountCredentials(service_account, data_dir + '/key.json')
#     ee.Initialize(credentials, project='dh-platform-rsde')
#
#     # Read AOI coordinates from config file
#     aoi_coordinates_str = config['INPUT'].get('aoi_path', '')
#     # Parse the coordinates string into a list of lists for ee.Geometry.Polygon
#     if aoi_coordinates_str:
#         aoi_coordinates = [
#             [float(coord.split(',')[0]), float(coord.split(',')[1])]
#             for coord in aoi_coordinates_str.split(';')
#         ]
#     else:
#         # Default AOI if not specified in config
#         aoi_coordinates = [
#         [10.42, 46.29],
#         [11.62, 46.29],
#         [11.62, 45.73],
#         [10.42, 45.73]
#     ]
#
#     # Define AOI (Area of Interest)
#     aoi = ee.Geometry.Polygon([aoi_coordinates])
#
#     print("AOI successfully loaded")
#
#     # Load CHIRPS data
#     chirps = ee.ImageCollection('UCSB-CHG/CHIRPS/PENTAD') \
#     .filterBounds(aoi) \
#     .filterDate(chirps_start_date, chirps_end_date)  # Use config dates
#
#     # Function to add date as a property to each image
#     def add_date_property(image):
#         return image.set('date', image.date().format('YYYY-MM-dd'))
#
#     # Map the function to the collection
#     chirps_with_date = chirps.map(add_date_property)
#
#     # Reduce the CHIRPS data to mean precipitation values over the AOI
#     def extract_precipitation(image):
#         mean_precip = image.reduceRegion(
#             reducer=ee.Reducer.mean(),
#             geometry=aoi,
#             scale=1000
#         ).get('precipitation')  # Key for precipitation in CHIRPS
#         return ee.Feature(None, {'date': image.get('date'), 'precipitation': mean_precip})
#
#     precipitation_features = chirps_with_date.map(extract_precipitation)
#
#     # Convert to list of dictionaries
#     precipitation_list = precipitation_features.getInfo()['features']
#
#     # Extract dates and precipitation into a DataFrame
#     data = pd.DataFrame([
#         {'Date': f['properties']['date'], 'Precipitation': f['properties']['precipitation']}
#         for f in precipitation_list
#     ])
#
#     print(data)
#     project.log_dataitem("precipitation", data=data, kind='table')
#     # project.log_dataitem("comuni", data=df, kind='table', index=False)
# Out:
# Overwriting src/flood-map.py

# %%
func_flood_map = project.new_function(
    name="flood-map",
    kind="python",
    python_version="PYTHON3_10",
    source={"source": "src/flood-map.py", "handler": "load"},
    requirements=['earthengine-api', 'geemap', 'numpy', 'ipyleaflet']
)

# %%
run_flood_map = func_flood_map.run(action="job", inputs={'config': di.key}, local_execution=False)

# %% [markdown]
# # Graph

# %%
precipitaion = project.get_dataitem('precipitation')
data = precipitaion.as_df()
data
# Out:
#           Date  Precipitation
# 0   2018-07-01      19.662261
# 1   2018-07-06       9.385073
# 2   2018-07-11      19.751829
# 3   2018-07-16      16.866667
# 4   2018-07-21      29.674681
# 5   2018-07-26      13.996076
# 6   2018-08-01      37.619412
# 7   2018-08-06      12.560494
# 8   2018-08-11       8.685839
# 9   2018-08-16       7.249457
# 10  2018-08-21      25.425021
# 11  2018-08-26      40.404386
# 12  2018-09-01      36.377751
# 13  2018-09-06       8.039738
# 14  2018-09-11       6.541906
# 15  2018-09-16       3.942303
# 16  2018-09-21       6.617841
# 17  2018-09-26       3.383102
# 18  2018-10-01      12.327543
# 19  2018-10-06       7.839192
# 20  2018-10-11       2.549496
# 21  2018-10-16       2.393938
# 22  2018-10-21       2.800001
# 23  2018-10-26     131.689939
# 24  2018-11-01      38.853100
# 25  2018-11-06       1.300202
# 26  2018-11-11       1.277843
# 27  2018-11-16       1.601283
# 28  2018-11-21      14.368323
# 29  2018-11-26       2.556458

# %%
import matplotlib.pyplot as plt

# Convert date column to datetime
# data['Date'] = pd.to_datetime(data['Date'])
dataP = data.sort_values(by='Date')

# Plot the time series
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Precipitation'], color='blue', label='Precipitation (mm/pentad)')
plt.xlabel('Date')
plt.ylabel('Precipitation (mm/perday)')
plt.title('Precipitation Full Time Series (2018)') #change the title accordingly
plt.legend()
plt.grid(True)
plt.show()

# %%
import plotly.express as px

fig = px.line(data, x='Date', y='Precipitation', title='Precipitation Time Series (2018)', #change the year accordingly
              labels={'Precipitation': 'Precipitation (mm/perday)', 'Date': 'Date'})
fig.show()
